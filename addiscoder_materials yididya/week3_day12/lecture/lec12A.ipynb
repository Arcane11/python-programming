# %% [markdown]
# # Introduction to Sorting
#
# For additional reading and resources, you can refer to https://jeffe.cs.illinois.edu/teaching/algorithms/book/00-intro.pdf and https://jeffe.cs.illinois.edu/teaching/algorithms/book/01-recursion.pdf
#
# For this set of lecture notes in particular, I also referenced https://courses.grainger.illinois.edu/cs277/fa2021/assets/lectures/slides/cs277-10-Sorting.pdf which might be helpful for students.
#
# Yesterday, we covered binary search where we find for a value in a list by cutting down the search space of our algorithm. However, for binary search to work, we learned that an array needs to be sorted. Today, we will start learning about some algorithms for sorting.
#
# ## Why does sorting matter?
# - Sorting is a fundamental problem in computer science
# - Many algorithms begin with or include a sorting step
# - What are some things you can sort? Discuss with a student beside you!
#
# ## Human sorting
# Let's say we have the following random numbers:
# ![Screen%20Shot%202023-07-31%20at%207.08.17%20AM.png](attachment:Screen%20Shot%202023-07-31%20at%207.08.17%20AM.png)
#
# If we want to order these numbers from the SMALLEST number to the LARGEST number, how could we do that? Discuss with your neighbor again.

# %%
# Sorting the above numbers: [8, 4, 3, 0, 9, 6, 1, 2, 5, 7]

# %% [markdown]
# One of the most straightforward ways to sort is to try and compare elements with one another and "bubble up" larger values in the array. This algorithm is also known as Bubble Sort.
#
# ## Bubble Sort
#
# For bubble sort, we will take the following approach:
# 1. Compare element i with its neighbor
# 2. Swap i and its neighbor if i is greater
# 3. After, reduce the problem space
#
# We need to do this until we have a sorted array which is when our problem space is size 1.

# %%
# bubble sort implementation in pseudocode

# %% [markdown]
# What is the time complexity of bubble sort?

# %%
#

# %% [markdown]
# Let's look at another sorting algorithm:
#
# ## Selection Sort
#
# In selection sort, we can select the lowest value each time in the array and put it into a sorted section of the array. We want to keep track of where we insert the smallest element and the smallest element. Below is a visual representation:
#
# ![image.png](attachment:image.png)

# %%
# In person demonstration

# %% [markdown]
# Now, let's try to implement selection sort in code:

# %%
def selection_sort(arr):
    pass

# %%
l_unsorted = [7, 2, 6, 0, 18, 4, 9]

# %%
selection_sort(l_unsorted)
print(l_unsorted)

# %% [markdown]
# The above code we wrote is an iterative implementation of selection sort. Similar to binary search, this code can also be written recursively! We won't cover this in class, but in your lab you will attempt to write a recursive selection sort.
#
# ## Time Complexity of Selection Sort
#
# Let's evaluate the function we wrote above for selection sort. We can evaluate this line by line:

# %%
# Selection sort function

# %% [markdown]
# ## Additional Notes
#
# The selection sort code we wrote above is an IN PLACE implementation. This means we do not create a new array to store the sorted values, but instead do all operations inside the existing array.
#
# The selection sort code we wrote above is also not a STABLE sort. This means for elements of the same value, they don't necessarily retain their order from the original input.
